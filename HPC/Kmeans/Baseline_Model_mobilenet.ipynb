# %%
import Category_Prediction_Mobilenet
import Kmeans_Mobile as mb
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\avadh\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# C:\Users\avadh\Anaconda3\envs\tensorflow\lib\site-packages\keras_applications\mobilenet.py:208: UserWarning: MobileNet shape is undefined. Weights for input shape (224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'

# %%
# Category Prediction

model_path = "C:/Users/avadh/Desktop/295B/FinishedModel/model_mobilenet_semi.z"
image_path = "C:/Users/avadh/Desktop/295B/visualsearch-master/files/images/Semi_images"
train_path = "C:/Users/avadh/Desktop/295B/visualsearch-master/files/images/Semi_train"
query_path = "C:/Users/avadh/Desktop/295B/visualsearch-master/files/images/query_images/13281_shop_01.jpg"
pickle_path = "C:/Users/avadh/Desktop/295B/Final_Model/Pickles/features_mnet/"

pred_categories = Category_Prediction_Mobilenet.mobilenet_prediction(model_path,query_path)

print("Top 3 categories with probabilities:",pred_categories)
# Out:
# C:\Users\avadh\Anaconda3\envs\tensorflow\lib\site-packages\keras_applications\mobilenet.py:208: UserWarning: MobileNet shape is undefined. Weights for input shape (224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'
# probs [[9.51168523e-01 4.22701015e-04 4.63829116e-03 2.07413827e-03
#   4.16963465e-02]]
# Top 3 categories with probabilities: [(0.9511685231044686, 'Chiffon'), (0.04169634645808177, 'Skirt'), (0.0046382911576115056, 'Lace_Dress')]

# %%
#Image Similarity

# pred_cats = []

# for i in range(len(pred_categories)):
#     print(type(pred_categories[i][1]))
# #     pred_cats.append(i[1])

    

mb.kmeans_model(pred_categories,image_path,pickle_path,query_path)
# Out:
# C:\Users\avadh\Anaconda3\envs\tensorflow\lib\site-packages\keras_applications\mobilenet.py:208: UserWarning: MobileNet shape is undefined. Weights for input shape (224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'
# image_names_len 5359
# mnetloaded (5359, 50176)
# processedpickleimage 3
# processed_pickle_images_np (5359, 50176)
# type processed np <class 'numpy.ndarray'>
# klabels [0 1 1 ... 0 1 1]
# klabels 5359
# (1, 50176)
# [1]
# position 5359
# count 2280
# [(0.2583318508238163, 'Chiffon/6015_shop_01.jpg'), (0.22434465362155764, 'Chiffon/6175_comsumer_03.jpg'), (0.22041106369540858, 'Chiffon/5750_shop_01.jpg'), (0.21885886532055213, 'Chiffon/6542_comsumer_02.jpg'), (0.21622076305678992, 'Chiffon/5482_shop_01.jpg'), (0.21549859409578323, 'Chiffon/5900_shop_05.jpg')]
# Query image ==========================================
# Result images ========================================
# similarity 0.2583318508238163
# similarity 0.22434465362155764
# ...
